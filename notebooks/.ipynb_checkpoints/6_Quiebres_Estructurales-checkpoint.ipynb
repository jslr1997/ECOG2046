# %%
import pandas as pd
import numpy as np 
import statsmodels.api as sm
from statsmodels.tsa.arima_process import arma_generate_sample
import matplotlib.pyplot as plt 

# %matplotlib inline
from scipy import stats
from statsmodels.graphics.api import qqplot

from statsmodels.tsa.stattools import adfuller, zivot_andrews

# %% [markdown]
# # Introducción
#
# Cuando se realizan pruebas de raíz unitaria, se debe tener cuidado si se sospecha que ha ocurrido un cambio estructural. Cuando hay rupturas estructurales, los estadísticos de la prueba Dickey-Fuller están sesgadas hacia el no rechazo de una raíz unitaria.

# %%
n =240

y = np.zeros(n) 
z = np.zeros(n)
trend = np.zeros(n) 

for i in range(0,n):
    
    e = np.random.normal(0, 1, 1)
    
    trend[i]=i
    
    if i>=120:
        y[i] = 0.50*y[i-1] + 10 + e
        
    else:
        y[i]=0.5*y[i-1]+e
        
        
    if i==120:
        z[i] = z[i-1] + 10 + e
    else:
        z[i]=z[i-1]+e

y = pd.Series(y)    
z = pd.Series(z)  

frame = {'y':y,'z':z,'t':trend}

df = pd.DataFrame(frame) 
df.index = pd.period_range('1981-01-01', '2000-12-01', freq='M')

# df['d'] = (df.index >= '1990-01-01').astype(int)

# %%
figure, axes = plt.subplots(2, 1)
df['y'].plot(ax=axes[0],figsize=(12,8))
df['z'].plot(ax=axes[1],figsize=(12,8))

# %%
df
# Out:
#                  y          z      t
# 1981-01  -0.848268  -0.848268    0.0
# 1981-02   0.228293  -0.195841    1.0
# 1981-03   1.076503   0.766516    2.0
# 1981-04   0.864043   1.092307    3.0
# 1981-05   0.318440   0.978726    4.0
# ...            ...        ...    ...
# 2000-08  20.894269  16.238837  235.0
# 2000-09  19.032255  14.823957  236.0
# 2000-10  19.179785  14.487615  237.0
# 2000-11  18.234547  13.132269  238.0
# 2000-12  18.947135  12.962131  239.0
#
# [240 rows x 3 columns]

# %%
def adf_test(timeseries,exog):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, maxlag=5,regression=exog,autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %% [markdown]
# ## Test DF: Z and Y

# %%
adf_test(df['y'],'ct')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -2.151423
# p-value                          0.517208
# #Lags Used                       0.000000
# Number of Observations Used    239.000000
# Critical Value (1%)             -3.997157
# Critical Value (5%)             -3.429021
# Critical Value (10%)            -3.137939
# dtype: float64

# %%
adf_test(df['z'],'ct')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.865568
# p-value                          0.672318
# #Lags Used                       0.000000
# Number of Observations Used    239.000000
# Critical Value (1%)             -3.997157
# Critical Value (5%)             -3.429021
# Critical Value (10%)            -3.137939
# dtype: float64

# %% [markdown]
# ## Estimacion de la regresion
#
# $\Delta y_t  = a_0 + \gamma y_{t − 1} + a_2t + e_t$

# %%
df['ly']=df['y'].shift()
df['dy']=df['y'].diff()
df['dly1']=df['dy'].shift()
df['dly2']=df['dy'].shift(periods=2)
# df['dly3']=df['dy'].shift(periods=3)
df['lz']=df['z'].shift()
df['dz']=df['z'].diff()
df['dlz1']=df['dz'].shift()
df['dlz2']=df['dz'].shift(periods=2)
df=df[3:]

# %%
df.head()
# Out:
#                 y         z    t        ly        dy      dly1      dly2  \
# 1981-04  0.773105  0.208898  3.0  0.565332  0.207773  1.669065 -0.513723
# 1981-05  1.143052  0.965397  4.0  0.773105  0.369947  0.207773  1.669065
# 1981-06  0.465810  0.859681  5.0  1.143052 -0.677242  0.369947  0.207773
# 1981-07  0.872071  1.498848  6.0  0.465810  0.406261 -0.677242  0.369947
# 1981-08  1.733727  2.796539  7.0  0.872071  0.861656  0.406261 -0.677242
#
#                lz        dz      dlz1      dlz2
# 1981-04 -0.281541  0.490439  1.117198 -0.808728
# 1981-05  0.208898  0.756499  0.490439  1.117198
# 1981-06  0.965397 -0.105716  0.756499  0.490439
# 1981-07  0.859681  0.639166 -0.105716  0.756499
# 1981-08  1.498848  1.297691  0.639166 -0.105716

# %%
X1 = [df['t'],df['ly']]
X1 = np.column_stack(X1)
X1 = sm.add_constant(X1)

model1 = sm.OLS(df['dy'],X1)
results1 = model1.fit()

print(results1.summary(xname=['const','trend','ly']))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     dy   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     2.407
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):             0.0923
# Time:                        14:49:25   Log-Likelihood:                -412.25
# No. Observations:                 237   AIC:                             830.5
# Df Residuals:                     234   BIC:                             840.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1442      0.207     -0.698      0.486      -0.551       0.263
# trend          0.0051      0.003      1.959      0.051   -2.82e-05       0.010
# ly            -0.0388      0.018     -2.190      0.030      -0.074      -0.004
# ==============================================================================
# Omnibus:                      151.475   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2263.068
# Skew:                           2.206   Prob(JB):                         0.00
# Kurtosis:                      17.481   Cond. No.                         321.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X2 = [df['t'],df['lz']]
X2 = np.column_stack(X2)
X2 = sm.add_constant(X2)

model2 = sm.OLS(df['dz'],X2)
results2 = model2.fit()

print(results2.summary(xname=['const','trend','lz']))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     dz   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     1.859
# Date:                Thu, 09 Jul 2020   Prob (F-statistic):              0.158
# Time:                        14:49:26   Log-Likelihood:                -379.86
# No. Observations:                 237   AIC:                             765.7
# Df Residuals:                     234   BIC:                             776.1
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0223      0.160     -0.139      0.889      -0.338       0.293
# trend          0.0022      0.001      1.550      0.122      -0.001       0.005
# lz            -0.0316      0.017     -1.852      0.065      -0.065       0.002
# ==============================================================================
# Omnibus:                      199.582   Durbin-Watson:                   1.859
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6322.523
# Skew:                           2.970   Prob(JB):                         0.00
# Kurtosis:                      27.596   Cond. No.                         283.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Evaluamos la hipotesis
#
# $\gamma = a_2 =0$

# %%
print(results1.f_test('x1=x2=0'))
# Out:
# <F test: F=array([[2.40668507]]), p=0.09234103492693732, df_denom=234, df_num=2>

# %%
print(results2.f_test('x1=x2=0'))
# Out:
# <F test: F=array([[1.85853875]]), p=0.15819420745300874, df_denom=234, df_num=2>

# %% [markdown]
# <img src="fig9.png" align="center"  width="500" height="350">

# %% [markdown]
# ## Paso 4: Evaluamos la raiz unitaria sin tendencia

# %%
zivot_andrews(df['y'],trim=0.15,maxlag=None,regression='c',autolag='AIC')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-264-184c057f174b> in <module>
# ----> 1 zivot_andrews(df['y'],trim=0.15,maxlag=None,regression='c',autolag='AIC')
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in __call__(self, x, trim, maxlag, regression, autolag)
#    2035                  autolag='AIC'):
#    2036         return self.run(x, trim=trim, maxlag=maxlag, regression=regression,
# -> 2037                         autolag=autolag)
#    2038
#    2039
#
# ~\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in run(self, x, trim, maxlag, regression, autolag)
#    1979                                  options=('c', 't', 'ct'))
#    1980         autolag = string_like(autolag, 'autolag',
# -> 1981                               options=('AIC', 'BIC', 't-stat'), optional=True)
#    1982         if trim < 0 or trim > (1. / 3.):
#    1983             raise ValueError('trim value must be a float in range [0, 1/3)')
#
# ~\Anaconda3\lib\site-packages\statsmodels\tools\validation\validation.py in string_like(value, name, optional, options, lower)
#     361         msg = '{0}{1} must be one of: {2}'.format(extra_text,
#     362                                                   name, options_text)
# --> 363         raise ValueError(msg)
#     364     return value
#     365
#
# ValueError: If not None, autolag must be one of: 'AIC', 'BIC', 't-stat'

# %% [markdown]
# ## Paso 5: Estimamos la regresion
#
# $\Delta y_t  = a_0 + \gamma y_{t − 1} + e_t$

# %%
X = [dfy['ly']]
X= np.column_stack(X)
X=sm.add_constant(X)

model = sm.OLS(dfy['dy'],X)
results = model.fit()

print(results.summary(xname=['const','ly']))
# print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     dy   R-squared:                       0.105
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     11.38
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):            0.00107
# Time:                        14:03:04   Log-Likelihood:                -207.68
# No. Observations:                  99   AIC:                             419.4
# Df Residuals:                      97   BIC:                             424.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2224      0.447      7.211      0.000       2.336       4.109
# ly            -0.0119      0.004     -3.374      0.001      -0.019      -0.005
# ==============================================================================
# Omnibus:                        3.342   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.188   Jarque-Bera (JB):                1.946
# Skew:                          -0.027   Prob(JB):                        0.378
# Kurtosis:                       2.315   Cond. No.                         282.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Evaluamos la hipotesis
#
# $\gamma = a_0 =0$

# %%
print(results.f_test('const=x1=0'))
# print(results.t_test('x1=0'))
# Out:
# <F test: F=array([[49.52636321]]), p=1.5078013611592429e-15, df_denom=97, df_num=2>

# %% [markdown]
# # Ejemplo 2

# %% [markdown]
# ## Paso 1: plot x

# %%
dfx['x'].plot(figsize=(12,8))

# %% [markdown]
# ## Paso 2: test ADF

# %%
adf_test(dfx['x'],'ct')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.567492e+00
# p-value                        3.511156e-12
# #Lags Used                     0.000000e+00
# Number of Observations Used    9.800000e+01
# Critical Value (1%)           -4.054251e+00
# Critical Value (5%)           -3.456279e+00
# Critical Value (10%)          -3.153866e+00
# dtype: float64

# %% [markdown]
# # Ejemplo Pib Ecuador

# %%
# Importar la data

df = pd.read_csv(r'CTASTRIM110.csv',header=0)
df['t']=df.index.values
df.index = pd.period_range('2000Q1', '2019Q4', freq='Q')

# %%
# Generar algunas variables

df['y']=np.log(df['pib'])
df['ly']=df['y'].shift()
df['dy']=df['y'].diff()
df['dly']=df['dy'].shift()
df=df[2:]

# %%
# Graficar la serie

df['y'].plot(figsize=(12,8))

# %%
# Testear ADF con constante y tendencia

adf_test(df['y'],'ct')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -0.150191
# p-value                         0.992349
# #Lags Used                      1.000000
# Number of Observations Used    76.000000
# Critical Value (1%)            -4.083117
# Critical Value (5%)            -3.469926
# Critical Value (10%)           -3.161802
# dtype: float64

# %%
df.loc[:,::-1]
# Out:
#              dly        dy         ly          y   t       pib  \
# 2000Q3  0.020139  0.024176  16.047718  16.071894   2   9548491
# 2000Q4  0.024176  0.018103  16.071894  16.089996   3   9722918
# 2001Q1  0.018103 -0.002426  16.089996  16.087571   4   9699363
# 2001Q2 -0.002426  0.010568  16.087571  16.098139   5   9802413
# 2001Q3  0.010568  0.000721  16.098139  16.098860   6   9809483
# ...          ...       ...        ...        ...  ..       ...
# 2018Q4  0.007641  0.000172  16.710363  16.710534  75  18083933
# 2019Q1  0.000172 -0.007003  16.710534  16.703531  76  17957733
# 2019Q2 -0.007003  0.003960  16.703531  16.707491  77  18028980
# 2019Q3  0.003960 -0.000385  16.707491  16.707106  78  18022042
# 2019Q4 -0.000385 -0.006774  16.707106  16.700332  79  17900370
#
#         servicios financieros  construccion  electricidad y agua  manufactura  \
# 2000Q3                 199255        584021               127071      1163347
# 2000Q4                 205530        606306               130164      1175038
# 2001Q1                 173319        646343               125913      1194620
# 2001Q2                 181735        679647               126847      1205261
# 2001Q3                 185457        719479               129345      1208396
# ...                       ...           ...                  ...          ...
# 2018Q4                 623886       1501173               498388      2095890
# 2019Q1                 621668       1476298               545837      2109667
# 2019Q2                 632152       1469861               568869      2132482
# 2019Q3                 633668       1477438               543705      2141289
# 2019Q4                 638864       1451078               575251      2106138
#
#         refinacion petroleo  petroleo y minas   pesca  acuicultura y camaron  \
# 2000Q3               305580            964910   67215                  16938
# 2000Q4               301765            969273   69094                  17338
# 2001Q1               273045           1009422   69754                  20274
# 2001Q2               272351            987165   70063                  21160
# 2001Q3               252792            981463   69372                  21932
# ...                     ...               ...     ...                    ...
# 2018Q4               156829           1581110  113114                 210752
# 2019Q1               139184           1582616  117164                 222482
# 2019Q2               125218           1602148  120455                 230124
# 2019Q3               132795           1640124  123511                 229922
# 2019Q4               121985           1582924  108645                 230959
#
#         agricultura datetime  quarter  year
# 2000Q3       795921   2000q3        3  2000
# 2000Q4       806318   2000q4        4  2000
# 2001Q1       831433   2001q1        1  2001
# 2001Q2       832327   2001q2        2  2001
# 2001Q3       853085   2001q3        3  2001
# ...             ...      ...      ...   ...
# 2018Q4      1369397   2018q4        4  2018
# 2019Q1      1394325   2019q1        1  2019
# 2019Q2      1388267   2019q2        2  2019
# 2019Q3      1369858   2019q3        3  2019
# 2019Q4      1391576   2019q4        4  2019
#
# [78 rows x 18 columns]

# %%
# Estimar la ecuacion

X = [df['t'],df['ly'],df['dly']]
X= np.column_stack(X)
X=sm.add_constant(X)

model = sm.OLS(df['dy'],X)
results = model.fit()

print(results.summary(xname=['const','t','ly','dly']))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     dy   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.157
# Method:                 Least Squares   F-statistic:                     5.793
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):            0.00130
# Time:                        14:37:35   Log-Likelihood:                 252.29
# No. Observations:                  78   AIC:                            -496.6
# Df Residuals:                      74   BIC:                            -487.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1411      0.454      0.310      0.757      -0.764       1.047
# t          -3.141e-05      0.000     -0.115      0.909      -0.001       0.001
# ly            -0.0082      0.028     -0.288      0.774      -0.065       0.048
# dly            0.3117      0.115      2.714      0.008       0.083       0.541
# ==============================================================================
# Omnibus:                        7.339   Durbin-Watson:                   2.021
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                7.713
# Skew:                          -0.497   Prob(JB):                       0.0211
# Kurtosis:                       4.177   Cond. No.                     2.00e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(results.f_test('x1=x2=0'))
# Out:
# <F test: F=array([[2.22689505]]), p=0.11504248445077403, df_denom=74, df_num=2>

# %%
# Testear ADF sin tendencia

adf_test(df['y'],'c')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -1.863591
# p-value                         0.349378
# #Lags Used                      1.000000
# Number of Observations Used    76.000000
# Critical Value (1%)            -3.519481
# Critical Value (5%)            -2.900395
# Critical Value (10%)           -2.587498
# dtype: float64

# %%
#Estimar la ecuacion

X = [df['ly'],df['dly']]
X= np.column_stack(X)
X=sm.add_constant(X)

model = sm.OLS(df['dy'],X)
results = model.fit()

print(results.summary(xname=['const','ly','dly']))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     dy   R-squared:                       0.190
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     8.798
# Date:                Thu, 02 Jul 2020   Prob (F-statistic):           0.000369
# Time:                        15:13:36   Log-Likelihood:                 252.28
# No. Observations:                  78   AIC:                            -498.6
# Df Residuals:                      75   BIC:                            -491.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1923      0.088      2.178      0.033       0.016       0.368
# ly            -0.0114      0.005     -2.121      0.037      -0.022      -0.001
# dly            0.3158      0.109      2.908      0.005       0.099       0.532
# ==============================================================================
# Omnibus:                        7.323   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.026   Jarque-Bera (JB):                7.710
# Skew:                          -0.495   Prob(JB):                       0.0212
# Kurtosis:                       4.181   Cond. No.                     1.72e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.72e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
print(results.f_test('const=x1=0'))
# Out:
# <F test: F=array([[8.55385236]]), p=0.0004505042316172856, df_denom=75, df_num=2>

# %% [markdown]
# # Tablas
#
# <img src="fig6.png" align="left"  width="300" height="250" > <img src="fig7.png" align="right" width="300" height="250">

# %% [markdown]
# # Referencias
#
# [Enders, W (2015)](https://www.amazon.com/Applied-Econometric-Wiley-Probability-Statistics/dp/1118808568/ref=sr_1_1?dchild=1&keywords=applied+time+series+econometrics&qid=1590717656&sr=8-1)
