# %%
import pandas as pd
import numpy as np 
import statsmodels.api as sm
from statsmodels.tsa.arima_process import arma_generate_sample
import matplotlib.pyplot as plt 

# %matplotlib inline
from scipy import stats
from statsmodels.graphics.api import qqplot

# %% [markdown]
# # Introduccion
#
# Hemos estudiado series temporales que no exhibieron un crecimiento a largo plazo, es decir no tienen una media constante. Sin embargo, muchas series de tiempo económicas y financieras no tienen una media constante. Los ejemplos incluyen: el PIB y el IPC de Ecuador.

# %% [markdown]
# # Diferenciación
#
# La diferenciación de una serie es un concepto similar a la derivada. Básicamente, la diferenciación es el cambio de una serie $x$ de un periodo a otro, $\Delta x_t= x_t-x_{t-1}$. En este caso, la seria $x_t$ es integrada de orden 1 si luego de diferenciarla 1 vez se convierte en estacionaria.
#
# De manera general, decimos que una serie es integrada de orden $d$ si luego de diferenciarla d veces se convierte en estacionaria. Es decir, $\Delta^d x_t=(1-L)^d x_t$
#
# - Si $d=1$, $\Delta x_t= x_t-x_{t-1}$
#
# - Si $d=2$, $\Delta^2 x_t= (1-L)^2x_t=(1-2L+L^2) x_t- x_t -x_{t-1}-x_{t-1}+x_{t-2}=\Delta x_t-\Delta x_{t-1}$,
#
#
# La diferenciación no elimina todas la no estacionariedad; solo elimina la asociada con la integración. En este contexto, pasamos del modelo $ARMA(p,q)$ al $ARIMA(p,d,q)$, donde $d$ indican las veces que debemos diferenciar las serie para que sea estacionaria. En primer lugar, necesitamos conocer cuántas veces hay que diferenciar una seria para convertirla en estacionaria. Luego, se procede con la parte $ARMA(p,q)$.
#
# A continuación, exploraremos cómo la diferenciación afecta tres procesos no estacionarios diferentes: una caminata aleatoria, una caminata aleatoria con drift y un modelo de tendencia determinista. Veremos que la dificultad radica en determinar si la variable es estacionaria después de las diferencias "d". Las diferencias erróneas se suman a nuestro problema, por lo que no es una solución automática.

# %% [markdown]
# # Caminata aleatoria (random walk)
#
# Consideramos el modelo $y_t = y_{t-1}+e_t$

# %% [markdown]
# ## Generando una caminata aleatoria

# %%
arparams = np.array([1, -1])
maparams = np.array([1])

nobs = 240

y = arma_generate_sample(arparams, maparams, nobs)

# %%
y=pd.DataFrame(y, columns=['y'])
y.index = pd.period_range('1981-01-01', '2000-12-01', freq='M')

# %%
y.plot(figsize=(12,8))

# %% [markdown]
# ## Gráfico de ACF y PACF

# %%
fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(y, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(y, lags=40, ax=ax2)

# %% [markdown]
# ## Estimación del modelo

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(y, order=(1,0,0), trend=None)

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  240
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -342.639
# Date:                Tue, 23 Jun 2020   AIC                            689.278
# Time:                        15:32:30   BIC                            696.240
# Sample:                    01-31-1981   HQIC                           692.083
#                          - 12-31-2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9895      0.009    113.910      0.000       0.972       1.006
# sigma2         1.0013      0.081     12.364      0.000       0.843       1.160
# ...
# Ljung-Box (Q):                       54.86   Jarque-Bera (JB):                 4.78
# ...

# %% [markdown]
# ## Análisis de los residuos

# %%
resid = results.resid

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)
ax = resid.plot(ax=ax)

# %%
fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(resid, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(resid, lags=40, ax=ax2)

# %% [markdown]
# ## Estimación del modelo transformado

# %%
dy = y['y'].diff(periods=1)

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)
ax = dy.plot(ax=ax)

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(y, order=(1,1,0), trend=None)

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  240
# Model:               SARIMAX(1, 1, 0)   Log Likelihood                -339.993
# Date:                Tue, 23 Jun 2020   AIC                            683.987
# Time:                        15:32:42   BIC                            690.940
# Sample:                    01-31-1981   HQIC                           686.789
#                          - 12-31-2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0145      0.066      0.219      0.827      -0.115       0.144
# sigma2         1.0073      0.084     12.036      0.000       0.843       1.171
# ...
# Ljung-Box (Q):                       55.38   Jarque-Bera (JB):                 3.48
# ...

# %%
resid1 = results.resid

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)
ax = resid1.plot(ax=ax)

# %% [markdown]
# ## Ejemplo: Euro-Dollar

# %%
# Importar data
df1 = pd.read_csv(r'euro_dolar.csv',header=0, parse_dates=True,squeeze=True)
df1.index = pd.period_range('2000-01-01', '2019-12-31',  freq='M')

# %%
df1.head()
# Out:
#            year  month   price    open    high     low  change
# 2000-01  2000.0      1  1.0313  0.9940  1.0339  0.9598   3.90%
# 2000-02  2000.0      2  1.0367  1.0304  1.0640  0.9907   0.52%
# 2000-03  2000.0      3  1.0459  1.0366  1.0551  1.0206   0.89%
# 2000-04  2000.0      4  1.0959  1.0455  1.1075  1.0251   4.78%
# 2000-05  2000.0      5  1.0662  1.0961  1.1308  1.0621  -2.71%

# %%
rate = df1['price']
drate = rate.diff(periods=1)

# %%
rate.plot(figsize=(15, 5),c='b')
plt.title(' Euro-Dolar: Exchange rate 2000m1 - 2019m12', c='r') 
# plt.ylabel('Miles de US ?dólares, 2007=100') 
# plt.axvline(x='2016-02-01',c='r')
# plt.axvline(x='2015-03-01',c='r')
# Out:
# Text(0.5, 1.0, ' Euro-Dolar: Exchange rate 2000m1 - 2019m12')

# %%
drate = drate.dropna()

# %%
drate.plot(figsize=(15, 5),c='b')
plt.title(' Euro-Dolar: Exchange rate 2000m1 - 2019m12', c='r') 
# plt.ylabel('Miles de US ?dólares, 2007=100') 
# plt.axvline(x='2016-02-01',c='r')
# plt.axvline(x='2015-03-01',c='r')
# Out:
# Text(0.5, 1.0, ' Euro-Dolar: Exchange rate 2000m1 - 2019m12')

# %%
fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(drate, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(drate, lags=40, ax=ax2)

# %% [markdown]
# # Modelo con tendencia determinística
#
# Consideramos el modelo $y_t = \beta_0 + \beta_1 t +e_t$

# %% [markdown]
# ## Generar el modelo con tendencia determinística

# %%
arparams = np.array([1, -1])
maparams = np.array([1])

nobs = 240

y = arma_generate_sample(arparams, maparams, nobs)

# %%
df=pd.DataFrame(y, columns=['y'])
df.index = pd.period_range('1981-01-01', '2000-12-01', freq='M')

df['e']=df['y'].diff(periods=1)
df['const']=1.2
df['trend']=range(0,240)
df['trend']= df['trend']*0.25

df['y']=df['const']+df['trend']+df['e']

# %%
df.head()
# Out:
#                 y         e  const  trend
# 1981-01       NaN       NaN    1.2   0.00
# 1981-02  1.611735  0.161735    1.2   0.25
# 1981-03  1.780572  0.080572    1.2   0.50
# 1981-04  1.853528 -0.096472    1.2   0.75
# 1981-05  1.596985 -0.603015    1.2   1.00

# %%
x = df['y'].dropna()

# %% [markdown]
# ## Gráfico ACF y PACF

# %%
fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(x, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(x, lags=40, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)
ax = x.plot(ax=ax)

# %% [markdown]
# ## Extraer la tendencia de la serie

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(x, order=(0,0,0), trend='ct')

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  239
# Model:                        SARIMAX   Log Likelihood                -343.564
# Date:                Thu, 25 Jun 2020   AIC                            693.127
# Time:                        14:46:36   BIC                            703.556
# Sample:                    02-28-1981   HQIC                           697.330
#                          - 12-31-2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.2918      0.141      9.169      0.000       1.016       1.568
# drift          0.2506      0.001    225.234      0.000       0.248       0.253
# sigma2         1.0378      0.091     11.347      0.000       0.859       1.217
# ...

# %% [markdown]
# ## Estimar el modelo sin tendencia

# %%
# Serie sin tendencia
x_new = results.resid

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)

ax = x_new.plot(ax=ax)

# %% [markdown]
# # Caminata aleatoria con trend y drift
#
# Consideramos el modelo $y_t = \beta_0 + y_{t-1}+e_t$

# %% [markdown]
# ## Generar la caminata aleatoria con trend y drift

# %%
arparams = np.array([1, -1])
maparams = np.array([1])

nobs = 240

y = arma_generate_sample(arparams, maparams, nobs)

# %%
df=pd.DataFrame(y, columns=['y'])
df.index = pd.period_range('1981-01-01', '2000-12-01', freq='M')

df['e']=df['y'].diff(periods=1)
df['const']=1.2
df['trend']=range(0,240)
df['trend']= df['trend']*0.25
df['ly']=df['y'].shift()
df['yf']=df['const']+df['trend']+df['e'] + df['ly']

# %%
df.head()
# Out:
#                 y         e  const  trend        ly        yf
# 1981-01  0.210505       NaN    1.2   0.00       NaN       NaN
# 1981-02 -1.297490 -1.507995    1.2   0.25  0.210505  0.152510
# 1981-03 -0.737145  0.560345    1.2   0.50 -1.297490  0.962855
# 1981-04  0.350770  1.087916    1.2   0.75 -0.737145  2.300770
# 1981-05  2.161181  1.810411    1.2   1.00  0.350770  4.361181

# %%
z = df['yf'].dropna()

# %% [markdown]
# ## Grafico ACF y PACF

# %%
fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(z, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(z, lags=40, ax=ax2)

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)
ax = z.plot(ax=ax)

# %% [markdown]
# ## Extraer la tendencia de la serie

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(z, order=(0,0,0), trend='ct')

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                     yf   No. Observations:                  239
# Model:                        SARIMAX   Log Likelihood                -761.622
# Date:                Thu, 25 Jun 2020   AIC                           1529.245
# Time:                        14:57:27   BIC                           1539.674
# Sample:                    02-28-1981   HQIC                          1533.448
#                          - 12-31-2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9138      0.792      1.154      0.249      -0.639       2.466
# drift          0.2305      0.007     34.502      0.000       0.217       0.244
# sigma2        34.3118      5.205      6.591      0.000      24.109      44.514
# ...

# %%
# Serie sin tendencia
z_new = results.resid

# %%
fig = plt.figure(figsize=(12,8))

ax = fig.add_subplot(111)

ax = z_new.plot(ax=ax)

# %% [markdown]
# ## Estimar modelo sin tendencia

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(z_new, order=(1,0,0), trend=None)

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  239
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -335.265
# Date:                Thu, 25 Jun 2020   AIC                            674.530
# Time:                        14:57:41   BIC                            681.483
# Sample:                    02-28-1981   HQIC                           677.332
#                          - 12-31-2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9852      0.011     93.546      0.000       0.965       1.006
# sigma2         0.9540      0.089     10.774      0.000       0.780       1.128
# ...
# Ljung-Box (Q):                       35.29   Jarque-Bera (JB):                 0.93
# ...

# %% [markdown]
# ## Analisis de residuos

# %%
res2 = results.resid

fig = plt.figure(figsize=(12,8))

#Plot ACF
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(res2, lags=40, ax=ax1)

#Plot PACF
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(res2, lags=40, ax=ax2)

# %% [markdown]
# ## Ejemplo: PIB

# %%
# Importar data
df1 = pd.read_csv(r'CTASTRIM110.csv',header=0, parse_dates=True,squeeze=True)
df1.index = pd.period_range('2000Q1', '2019Q4', freq='Q')

# %%
# Definir varibles
dpib = df1['pib'].diff(periods=1)
pib = df1['pib']

# %%
pib.plot(figsize=(15, 5),c='k')
plt.title(' Ecuador: PIB 2000q1 - 2019q4', c='b') 
plt.ylabel('Miles de US dólares, 2007=100')
# Out:
# Text(0, 0.5, 'Miles de US dólares, 2007=100')

# %%
# Generar el modelo
model = sm.tsa.SARIMAX(pib, order=(1,1,0), trend='c')

# Estimar los parametros del modelo
results = model.fit()

print(results.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                    pib   No. Observations:                   80
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -1054.396
# Date:                Tue, 23 Jun 2020   AIC                           2114.791
# Time:                        13:31:01   BIC                           2121.899
# Sample:                    03-31-2000   HQIC                          2117.639
#                          - 12-31-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   6.843e+04   1.45e+04      4.711      0.000       4e+04    9.69e+04
# ar.L1          0.0237      0.021      1.145      0.252      -0.017       0.064
# sigma2      1.874e+10      0.011   1.65e+12      0.000    1.87e+10    1.87e+10
# ...
